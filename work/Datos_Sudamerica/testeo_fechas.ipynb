# %%
import pandas as pd

#Lista de fechas
dias_consecutivos = ['2023-12-29','2024-01-01','2024-01-02','2024-01-06']

#Transforma las fechas a objeto datetime64. Lo convierte a dataframe
fechas_reales = pd.DataFrame({'Fecha':pd.to_datetime(dias_consecutivos)})

#Calcula el periodo teorico de datos que deberia haber entre el inicio y final
fechas_teoricas = pd.date_range(start=fechas_reales['Fecha'].min(),end=fechas_reales['Fecha'].max())

#Calcula la diferencia y encuentra que datos faltan
fechas_faltantes = set(fechas_teoricas) -  set(fechas_reales['Fecha'])

#Ordena estos datos cronologicamente
fechas_fantantes_ordenadas_crono = sorted(fechas_faltantes)

df = pd.DataFrame({'Datos faltantes':fechas_fantantes_ordenadas_crono})
df
# Out:
#   Datos faltantes
# 0      2023-12-30
# 1      2023-12-31
# 2      2024-01-03
# 3      2024-01-04
# 4      2024-01-05

# %%
class DatosTemporales():
    
    def __init__(self,lista_fechas):
        self.   
        
    def DatosFaltantes(self,output):

        #Transforma las fechas a objeto datetime64. Lo convierte a dataframe
        fechas_reales = pd.DataFrame({'Fecha':pd.to_datetime(self)})

        #Calcula el periodo teorico de datos que deberia haber entre el inicio y final
        fechas_teoricas = pd.date_range(start=fechas_reales['Fecha'].min(),end=fechas_reales['Fecha'].max())

        #Calcula la diferencia y encuentra que datos faltan
        fechas_faltantes = set(fechas_teoricas) -  set(fechas_reales['Fecha'])

        #Ordena estos datos cronologicamente
        fechas_fantantes_ordenadas_crono = sorted(fechas_faltantes)

        if output=='DataFrame':
            df = pd.DataFrame({'Datos faltantes':fechas_fantantes_ordenadas_crono})
            return df
        elif output=='list':
            return fechas_faltantes_ordenadas_crono
        else:
            return 'Formato incorrecto'
# Out:
#   Cell In[2], line 5
#     def DatosFaltantes(self,output):
#     ^
# IndentationError: expected an indented block after function definition on line 3

# %%
conjunto_datos = DatosTemporales()
dias_consecutivos

# %%
conjunto_datos

# %%
fechas_reales = pd.to_datetime(dias_consecutivos)
fechas_reales
# Out:
# DatetimeIndex(['2023-12-29', '2024-01-01', '2024-01-02', '2024-01-06'], dtype='datetime64[ns]', freq=None)

# %%
fechas_faltantes = set(fechas_teoricas) -  set(fechas_reales)
sorted(list(fechas_faltantes))
# Out:
# [Timestamp('2023-12-30 00:00:00'),
#  Timestamp('2023-12-31 00:00:00'),
#  Timestamp('2024-01-03 00:00:00'),
#  Timestamp('2024-01-04 00:00:00'),
#  Timestamp('2024-01-05 00:00:00')]

# %%
 set(fechas_reales)
# Out:
# {Timestamp('2023-12-29 00:00:00'),
#  Timestamp('2024-01-01 00:00:00'),
#  Timestamp('2024-01-02 00:00:00'),
#  Timestamp('2024-01-06 00:00:00')}

# %%
fechas_reales
# Out:
# DatetimeIndex(['2023-12-29', '2024-01-01', '2024-01-02', '2024-01-06'], dtype='datetime64[ns]', freq=None)

# %%
pd.date_range(start=fechas_reales.min(),end=fechas_reales.max())
# Out:
# DatetimeIndex(['2023-12-29', '2023-12-30', '2023-12-31', '2024-01-01',
#                '2024-01-02', '2024-01-03', '2024-01-04', '2024-01-05',
#                '2024-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame({"fecha": pd.to_datetime(dias_consecutivos)})
df
# Out:
#        fecha
# 0 2023-12-29
# 1 2024-01-01
# 2 2024-01-02
# 3 2025-01-06

# %%
print(df)
# Out:
#        fecha
# 0 2023-12-29
# 1 2024-01-01
# 2 2024-01-02
# 3 2025-01-06

# %%
import pandas as pd
import matplotlib.pyplot as plt

class ConjuntoDeDatos():
    
    def __init__(self,files):

        #Lista de archivos de mi conjunto de datos
        self.files = files

        #Dataframe que contiene las fechas de cada archivo en formato YYYY-MM-DD
        self.fechas_reales = pd.DataFrame({'Fecha': pd.to_datetime(files)})

    def faltantes(self,formato=None,outpath=None):
        fechas_teoricas = pd.date_range(start=self.fechas_reales['Fecha'].min(), end=self.fechas_reales['Fecha'].max())
        fechas_faltantes = set(fechas_teoricas) - set(self.fechas_reales['Fecha'])
        fechas_fantantes_ordenadas_crono = sorted(fechas_faltantes)

        df = pd.DataFrame({'Datos faltantes': fechas_fantantes_ordenadas_crono})
        df['Datos faltantes'] = pd.to_datetime(df['Datos faltantes']).dt.strftime('%Y-%m-%d')
        
        if formato is None and outpath is None:
            return df
        elif formato=='Grafico' and outpath is None:
            # Colorear el encabezado
            header_color = 'lightblue'

            # Crear una figura sin ejes
            fig, ax = plt.subplots(figsize=(6, 1))
            ax.axis('off')  # Ocultar ejes

            # Crear una tabla con el encabezado coloreado y valores del DataFrame
            tabla = ax.table(cellText=df.values, colLabels=df.columns, loc='center', cellLoc='center', colColours=[header_color]*len(df.columns), cellColours=[['white']*len(df.columns) for _ in range(len(df))])

            # Ajustar el diseño de la tabla
            tabla.auto_set_font_size(False)
            tabla.set_fontsize(10)
            tabla.scale(1.2, 1.2)
            plt.show()


          

        elif formato=='Grafico' and outpath is not None:

            header_color = 'lightblue'

            # Crear una figura sin ejes
            fig, ax = plt.subplots(figsize=(6, 1))
            ax.axis('off')  # Ocultar ejes
            
            # Crear una tabla con el encabezado coloreado y valores del DataFrame
            tabla = ax.table(cellText=df.values, colLabels=df.columns, loc='center', cellLoc='center', colColours=[header_color]*len(df.columns), cellColours=[['white']*len(df.columns) for _ in range(len(df))])

            # Ajustar el diseño de la tabla
            tabla.auto_set_font_size(False)
            tabla.set_fontsize(10)
            tabla.scale(1.2, 1.2)
            plt.savefig(outpath, bbox_inches='tight', pad_inches=0.5, dpi=300)  # Ajusta el valor de dpi según tus necesidades
        else:
            return 'Formato incorrecto'

# %%
algo = 'direc'
algo is  None
# Out:
# False

# %%
df.dt.strftime('%Y-%m-%d')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_25015/3200623981.py in ?()
# ----> 1 df.dt.strftime('%Y-%m-%d')
#
# ~/.conda/envs/tesis/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dt'

# %%
pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 2.1 MB/s eta 0:00:0000:0100:01
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# Uso de la clase
x = ['2023-12-29', '2024-01-01', '2024-01-02','A']

CD1= ConjuntoDeDatos(x)
CD1.faltantes(formato='Grafico')#,outpath='/home/fernando.huaranca/datosmunin3/ff.png')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[127], line 4
#       1 # Uso de la clase
#       2 x = ['2023-12-29', '2024-01-01', '2024-01-02','A']
# ----> 4 CD1= ConjuntoDeDatos(x)
#       5 CD1.faltantes(formato='Grafico')#,outpath='/home/fernando.huaranca/datosmunin3/ff.png')
#
# Cell In[123], line 12, in ConjuntoDeDatos.__init__(self, files)
#       9 self.files = files
#      11 #Dataframe que contiene las fechas de cada archivo en formato YYYY-MM-DD
# ---> 12 self.fechas_reales = pd.DataFrame({'Fecha': pd.to_datetime(files)})
#
# File ~/.conda/envs/tesis/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:1082, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1080         result = _convert_and_box_cache(argc, cache_array)
#    1081     else:
# -> 1082         result = convert_listlike(argc, format)
#    1083 else:
#    1084     result = convert_listlike(np.array([arg]), format)[0]
#
# File ~/.conda/envs/tesis/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:453, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     451 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     452 if format is not None and format != "mixed":
# --> 453     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     455 result, tz_parsed = objects_to_datetime64ns(
#     456     arg,
#     457     dayfirst=dayfirst,
#    (...)
#     461     allow_object=True,
#     462 )
#     464 if tz_parsed is not None:
#     465     # We can take a shortcut since the datetime64 numpy array
#     466     # is in UTC
#
# File ~/.conda/envs/tesis/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:484, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     473 def _array_strptime_with_fallback(
#     474     arg,
#     475     name,
#    (...)
#     479     errors: str,
#     480 ) -> Index:
#     481     """
#     482     Call array_strptime, with fallback behavior depending on 'errors'.
#     483     """
# --> 484     result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     485     if any(tz is not None for tz in timezones):
#     486         return _return_parsed_timezone_results(result, timezones, utc, name)
#
# File ~/.conda/envs/tesis/lib/python3.10/site-packages/pandas/_libs/tslibs/strptime.pyx:530, in pandas._libs.tslibs.strptime.array_strptime()
#
# File ~/.conda/envs/tesis/lib/python3.10/site-packages/pandas/_libs/tslibs/strptime.pyx:351, in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data "A" doesn't match format "%Y-%m-%d", at position 3. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %%
df.iloc[0].values
# Out:
# array(['2023-12-30T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
# Colorear el encabezado
header_color = 'lightblue'

# Crear una figura sin ejes
fig, ax = plt.subplots(figsize=(6, 2))
ax.axis('off')  # Ocultar ejes

# Crear una tabla con el encabezado coloreado y valores del DataFrame
tabla = ax.table(cellText=df.values, colLabels=df.columns, loc='center', cellLoc='center', colColours=[header_color]*len(df.columns), cellColours=[['white']*len(df.columns) for _ in range(len(df))])

# Ajustar el diseño de la tabla
tabla.auto_set_font_size(False)
tabla.set_fontsize(10)
tabla.scale(1.2, 1.2)

# Guardar la figura como una imagen con mayor resolución (dpi)
#plt.savefig('dataframe_coloreado.png', bbox_inches='tight', pad_inches=0.5, dpi=300)  # Ajusta el valor de dpi según tus necesidades

# Mostrar la figura (opcional)
plt.show()
